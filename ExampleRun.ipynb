# %%
import main

# %%
# %matplotlib inline

# %%
main.del_all()

# %%
main.update_database()
# Out:
# ***Fetching Email***
# !!! Upload failed for UID b'306' !!!
# !!! Upload failed for UID b'483' !!!
# !!! Upload failed for UID b'31' !!!
# !!! Upload failed for UID b'210' !!!
# !!! Upload failed for UID b'192' !!!
# !!! Upload failed for UID b'302' !!!
# !!! Upload failed for UID b'6' !!!
# !!! Upload failed for UID b'88' !!!
# !!! Upload failed for UID b'54' !!!
# !!! Upload failed for UID b'359' !!!
# !!! Upload failed for UID b'389' !!!
# !!! Upload failed for UID b'157' !!!
# !!! Upload failed for UID b'444' !!!
# !!! Upload failed for UID b'469' !!!
# !!! Upload failed for UID b'321' !!!
# !!! Upload failed for UID b'104' !!!
# !!! Upload failed for UID b'87' !!!
# !!! Upload failed for UID b'189' !!!
# !!! Upload failed for UID b'63' !!!
# !!! Upload failed for UID b'90' !!!
# !!! Upload failed for UID b'79' !!!
# !!! Upload failed for UID b'487' !!!
# !!! Upload failed for UID b'410' !!!
# !!! Upload failed for UID b'137' !!!
# !!! Upload failed for UID b'443' !!!
# !!! Upload failed for UID b'310' !!!
# !!! Upload failed for UID b'420' !!!
# !!! Upload failed for UID b'451' !!!
# !!! Upload failed for UID b'250' !!!
# !!! Upload failed for UID b'269' !!!
# !!! Upload failed for UID b'303' !!!
# !!! Upload failed for UID b'282' !!!
# !!! Upload failed for UID b'237' !!!
# !!! Upload failed for UID b'271' !!!
# !!! Upload failed for UID b'230' !!!
# !!! Upload failed for UID b'106' !!!
# !!! Upload failed for UID b'10' !!!
# !!! Upload failed for UID b'460' !!!
# !!! Upload failed for UID b'375' !!!
# !!! Upload failed for UID b'205' !!!
# !!! Upload failed for UID b'317' !!!
# !!! Upload failed for UID b'147' !!!
# !!! Upload failed for UID b'388' !!!
# !!! Upload failed for UID b'204' !!!
# !!! Upload failed for UID b'105' !!!
# !!! Upload failed for UID b'188' !!!
# !!! Upload failed for UID b'209' !!!
# !!! Upload failed for UID b'219' !!!
# !!! Upload failed for UID b'453' !!!
# !!! Upload failed for UID b'165' !!!
# !!! Upload failed for UID b'91' !!!
# !!! Upload failed for UID b'288' !!!
# !!! Upload failed for UID b'363' !!!
# !!! Upload failed for UID b'320' !!!
# !!! Upload failed for UID b'124' !!!
# !!! Upload failed for UID b'134' !!!
# !!! Upload failed for UID b'95' !!!
# !!! Upload failed for UID b'138' !!!
# !!! Upload failed for UID b'221' !!!
# !!! Upload failed for UID b'438' !!!
# !!! Upload failed for UID b'72' !!!
# !!! Upload failed for UID b'244' !!!
# !!! Upload failed for UID b'354' !!!
# !!! Upload failed for UID b'300' !!!
# !!! Upload failed for UID b'383' !!!
# !!! Upload failed for UID b'227' !!!
# !!! Upload failed for UID b'465' !!!
# !!! Upload failed for UID b'276' !!!
# !!! Upload failed for UID b'367' !!!
# !!! Upload failed for UID b'400' !!!
# !!! Upload failed for UID b'411' !!!
# !!! Upload failed for UID b'414' !!!
# !!! Upload failed for UID b'86' !!!
# !!! Upload failed for UID b'173' !!!
# !!! Upload failed for UID b'47' !!!
# !!! Upload failed for UID b'391' !!!
# !!! Upload failed for UID b'81' !!!
# !!! Upload failed for UID b'174' !!!
# !!! Upload failed for UID b'263' !!!
# !!! Upload failed for UID b'13' !!!
# !!! Upload failed for UID b'402' !!!
# !!! Upload failed for UID b'114' !!!
# !!! Upload failed for UID b'434' !!!
# !!! Upload failed for UID b'331' !!!
# !!! Upload failed for UID b'208' !!!
# !!! Upload failed for UID b'214' !!!
# !!! Upload failed for UID b'348' !!!
# !!! Upload failed for UID b'450' !!!
# !!! Upload failed for UID b'133' !!!
# !!! Upload failed for UID b'234' !!!
# !!! Upload failed for UID b'94' !!!
# !!! Upload failed for UID b'164' !!!
# !!! Upload failed for UID b'335' !!!
# !!! Upload failed for UID b'229' !!!
# !!! Upload failed for UID b'390' !!!
# !!! Upload failed for UID b'252' !!!
# !!! Upload failed for UID b'270' !!!
# !!! Upload failed for UID b'68' !!!
# !!! Upload failed for UID b'473' !!!
# !!! Upload failed for UID b'178' !!!
# !!! Upload failed for UID b'239' !!!
# !!! Upload failed for UID b'120' !!!
# !!! Upload failed for UID b'50' !!!
# !!! Upload failed for UID b'373' !!!
# !!! Upload failed for UID b'416' !!!
# !!! Upload failed for UID b'259' !!!
# !!! Upload failed for UID b'144' !!!
# !!! Upload failed for UID b'142' !!!
# !!! Upload failed for UID b'70' !!!
# !!! Upload failed for UID b'55' !!!
# !!! Upload failed for UID b'340' !!!
# !!! Upload failed for UID b'339' !!!
# !!! Upload failed for UID b'118' !!!
# !!! Upload failed for UID b'355' !!!
# !!! Upload failed for UID b'103' !!!
# !!! Upload failed for UID b'16' !!!
# !!! Upload failed for UID b'285' !!!
# !!! Upload failed for UID b'267' !!!
# !!! Upload failed for UID b'278' !!!
# !!! Upload failed for UID b'286' !!!
# !!! Upload failed for UID b'284' !!!
# !!! Upload failed for UID b'85' !!!
# !!! Upload failed for UID b'437' !!!
# !!! Upload failed for UID b'397' !!!
# !!! Upload failed for UID b'273' !!!
# !!! Upload failed for UID b'152' !!!
# !!! Upload failed for UID b'249' !!!
# !!! Upload failed for UID b'481' !!!
# !!! Upload failed for UID b'254' !!!
# !!! Upload failed for UID b'66' !!!
# !!! Upload failed for UID b'172' !!!
# !!! Upload failed for UID b'347' !!!
# !!! Upload failed for UID b'78' !!!
# !!! Upload failed for UID b'116' !!!
# !!! Upload failed for UID b'21' !!!
# !!! Upload failed for UID b'226' !!!
# !!! Upload failed for UID b'232' !!!
# !!! Upload failed for UID b'472' !!!
# !!! Upload failed for UID b'27' !!!
# !!! Upload failed for UID b'160' !!!
# !!! Upload failed for UID b'143' !!!
# !!! Upload failed for UID b'108' !!!
# !!! Upload failed for UID b'346' !!!
# !!! Upload failed for UID b'477' !!!
# !!! Upload failed for UID b'492' !!!
# !!! Upload failed for UID b'65' !!!
# !!! Upload failed for UID b'92' !!!
# !!! Upload failed for UID b'360' !!!
# !!! Upload failed for UID b'313' !!!
# !!! Upload failed for UID b'110' !!!
# !!! Upload failed for UID b'407' !!!
# !!! Upload failed for UID b'207' !!!
# !!! Upload failed for UID b'380' !!!
# !!! Upload failed for UID b'39' !!!
# !!! Upload failed for UID b'100' !!!
# !!! Upload failed for UID b'290' !!!
# !!! Upload failed for UID b'365' !!!
# !!! Upload failed for UID b'463' !!!
# !!! Upload failed for UID b'67' !!!
# !!! Upload failed for UID b'162' !!!
# !!! Upload failed for UID b'482' !!!
# !!! Upload failed for UID b'342' !!!
# !!! Upload failed for UID b'452' !!!
# !!! Upload failed for UID b'251' !!!
# !!! Upload failed for UID b'387' !!!
# !!! Upload failed for UID b'406' !!!
# !!! Upload failed for UID b'200' !!!
# !!! Upload failed for UID b'386' !!!
# !!! Upload failed for UID b'41' !!!
# !!! Upload failed for UID b'478' !!!
# !!! Upload failed for UID b'223' !!!
# !!! Upload failed for UID b'445' !!!
# !!! Upload failed for UID b'272' !!!
# !!! Upload failed for UID b'175' !!!
# !!! Upload failed for UID b'392' !!!
# !!! Upload failed for UID b'446' !!!
# !!! Upload failed for UID b'113' !!!
# !!! Upload failed for UID b'212' !!!
# !!! Upload failed for UID b'184' !!!
# !!! Upload failed for UID b'9' !!!
# !!! Upload failed for UID b'83' !!!
# !!! Upload failed for UID b'132' !!!
# !!! Upload failed for UID b'257' !!!
# !!! Upload failed for UID b'96' !!!
# !!! Upload failed for UID b'429' !!!
# !!! Upload failed for UID b'275' !!!
# !!! Upload failed for UID b'201' !!!
# !!! Upload failed for UID b'328' !!!
# !!! Upload failed for UID b'283' !!!
# !!! Upload failed for UID b'289' !!!
# !!! Upload failed for UID b'122' !!!
# !!! Upload failed for UID b'458' !!!
# !!! Upload failed for UID b'28' !!!
# !!! Upload failed for UID b'491' !!!
# !!! Upload failed for UID b'84' !!!
# !!! Upload failed for UID b'35' !!!
# !!! Upload failed for UID b'428' !!!
# !!! Upload failed for UID b'216' !!!
# !!! Upload failed for UID b'441' !!!
# !!! Upload failed for UID b'457' !!!
# !!! Upload failed for UID b'46' !!!
# !!! Upload failed for UID b'353' !!!
# !!! Upload failed for UID b'194' !!!
# !!! Upload failed for UID b'14' !!!
# !!! Upload failed for UID b'69' !!!
# !!! Upload failed for UID b'439' !!!
# !!! Upload failed for UID b'64' !!!
# !!! Upload failed for UID b'149' !!!
# !!! Upload failed for UID b'372' !!!
# !!! Upload failed for UID b'436' !!!
# !!! Upload failed for UID b'422' !!!
# !!! Upload failed for UID b'233' !!!
# !!! Upload failed for UID b'456' !!!
# !!! Upload failed for UID b'224' !!!
# !!! Upload failed for UID b'323' !!!
# !!! Upload failed for UID b'235' !!!
# !!! Upload failed for UID b'115' !!!
# !!! Upload failed for UID b'243' !!!
# !!! Upload failed for UID b'336' !!!
# !!! Upload failed for UID b'99' !!!
# !!! Upload failed for UID b'228' !!!
# !!! Upload failed for UID b'344' !!!
# !!! Upload failed for UID b'151' !!!
# !!! Upload failed for UID b'49' !!!
# !!! Upload failed for UID b'427' !!!
# !!! Upload failed for UID b'264' !!!
# !!! Upload failed for UID b'418' !!!
# !!! Upload failed for UID b'238' !!!
# !!! Upload failed for UID b'262' !!!
# !!! Upload failed for UID b'419' !!!
# !!! Upload failed for UID b'97' !!!
# !!! Upload failed for UID b'298' !!!
# !!! Upload failed for UID b'112' !!!
# !!! Upload failed for UID b'190' !!!
# !!! Upload failed for UID b'199' !!!
# !!! Upload failed for UID b'309' !!!
# !!! Upload failed for UID b'361' !!!
# !!! Upload failed for UID b'121' !!!
# !!! Upload failed for UID b'58' !!!
# !!! Upload failed for UID b'424' !!!
# !!! Upload failed for UID b'381' !!!
# !!! Upload failed for UID b'150' !!!
# !!! Upload failed for UID b'161' !!!
# !!! Upload failed for UID b'447' !!!
# !!! Upload failed for UID b'484' !!!
# !!! Upload failed for UID b'364' !!!
# !!! Upload failed for UID b'163' !!!
# !!! Upload failed for UID b'23' !!!
# !!! Upload failed for UID b'425' !!!
# !!! Upload failed for UID b'357' !!!
# !!! Upload failed for UID b'440' !!!
# !!! Upload failed for UID b'311' !!!
# !!! Upload failed for UID b'295' !!!
# !!! Upload failed for UID b'426' !!!
# !!! Upload failed for UID b'53' !!!
# !!! Upload failed for UID b'202' !!!
# !!! Upload failed for UID b'51' !!!
# !!! Upload failed for UID b'384' !!!
# !!! Upload failed for UID b'128' !!!
# !!! Upload failed for UID b'485' !!!
# !!! Upload failed for UID b'22' !!!
# !!! Upload failed for UID b'211' !!!
# !!! Upload failed for UID b'146' !!!
# !!! Upload failed for UID b'191' !!!
# !!! Upload failed for UID b'197' !!!
# !!! Upload failed for UID b'159' !!!
# !!! Upload failed for UID b'404' !!!
# !!! Upload failed for UID b'17' !!!
# !!! Upload failed for UID b'245' !!!
# !!! Upload failed for UID b'36' !!!
# !!! Upload failed for UID b'464' !!!
# !!! Upload failed for UID b'330' !!!
# !!! Upload failed for UID b'167' !!!
# !!! Upload failed for UID b'369' !!!
# !!! Upload failed for UID b'489' !!!
# !!! Upload failed for UID b'291' !!!
# !!! Upload failed for UID b'279' !!!
# !!! Upload failed for UID b'153' !!!
# !!! Upload failed for UID b'56' !!!
# !!! Upload failed for UID b'182' !!!
# !!! Upload failed for UID b'470' !!!
# !!! Upload failed for UID b'43' !!!
# !!! Upload failed for UID b'471' !!!
# !!! Upload failed for UID b'220' !!!
# !!! Upload failed for UID b'29' !!!
# !!! Upload failed for UID b'18' !!!
# !!! Upload failed for UID b'474' !!!
# !!! Upload failed for UID b'327' !!!
# !!! Upload failed for UID b'405' !!!
# !!! Upload failed for UID b'333' !!!
# !!! Upload failed for UID b'448' !!!
# !!! Upload failed for UID b'130' !!!
# !!! Upload failed for UID b'307' !!!
# !!! Upload failed for UID b'215' !!!
# !!! Upload failed for UID b'101' !!!
# !!! Upload failed for UID b'462' !!!
# !!! Upload failed for UID b'318' !!!
# !!! Upload failed for UID b'449' !!!
# !!! Upload failed for UID b'206' !!!
# !!! Upload failed for UID b'37' !!!
# !!! Upload failed for UID b'127' !!!
# !!! Upload failed for UID b'370' !!!
# !!! Upload failed for UID b'177' !!!
# !!! Upload failed for UID b'301' !!!
# !!! Upload failed for UID b'395' !!!
# !!! Upload failed for UID b'322' !!!
# !!! Upload failed for UID b'119' !!!
# !!! Upload failed for UID b'187' !!!
# !!! Upload failed for UID b'350' !!!
# !!! Upload failed for UID b'248' !!!
# !!! Upload failed for UID b'15' !!!
# !!! Upload failed for UID b'48' !!!
# !!! Upload failed for UID b'186' !!!
# !!! Upload failed for UID b'44' !!!
# !!! Upload failed for UID b'461' !!!
# !!! Upload failed for UID b'45' !!!
# !!! Upload failed for UID b'376' !!!
# !!! Upload failed for UID b'409' !!!
# !!! Upload failed for UID b'255' !!!
# !!! Upload failed for UID b'256' !!!
# !!! Upload failed for UID b'265' !!!
# !!! Upload failed for UID b'398' !!!
# !!! Upload failed for UID b'362' !!!
# !!! Upload failed for UID b'345' !!!
# !!! Upload failed for UID b'141' !!!
# !!! Upload failed for UID b'466' !!!
# !!! Upload failed for UID b'385' !!!
# !!! Upload failed for UID b'396' !!!
# !!! Upload failed for UID b'253' !!!
# !!! Upload failed for UID b'356' !!!
# !!! Upload failed for UID b'379' !!!
# !!! Upload failed for UID b'52' !!!
# !!! Upload failed for UID b'107' !!!
# !!! Upload failed for UID b'26' !!!
# !!! Upload failed for UID b'77' !!!
# !!! Upload failed for UID b'399' !!!
# !!! Upload failed for UID b'169' !!!
# !!! Upload failed for UID b'57' !!!
# !!! Upload failed for UID b'8' !!!
# !!! Upload failed for UID b'148' !!!
# !!! Upload failed for UID b'315' !!!
# !!! Upload failed for UID b'352' !!!
# !!! Upload failed for UID b'75' !!!
# !!! Upload failed for UID b'168' !!!
# !!! Upload failed for UID b'371' !!!
# !!! Upload failed for UID b'102' !!!
# !!! Upload failed for UID b'382' !!!
# !!! Upload failed for UID b'74' !!!
# !!! Upload failed for UID b'442' !!!
# !!! Upload failed for UID b'30' !!!
# !!! Upload failed for UID b'139' !!!
# !!! Upload failed for UID b'217' !!!
# !!! Upload failed for UID b'343' !!!
# !!! Upload failed for UID b'268' !!!
# !!! Upload failed for UID b'117' !!!
# !!! Upload failed for UID b'196' !!!
# !!! Upload failed for UID b'341' !!!
# !!! Upload failed for UID b'433' !!!
# !!! Upload failed for UID b'80' !!!
# !!! Upload failed for UID b'213' !!!
# !!! Upload failed for UID b'403' !!!
# !!! Upload failed for UID b'413' !!!
# !!! Upload failed for UID b'129' !!!
# !!! Upload failed for UID b'325' !!!
# !!! Upload failed for UID b'247' !!!
# !!! Upload failed for UID b'109' !!!
# !!! Upload failed for UID b'155' !!!
# !!! Upload failed for UID b'11' !!!
# !!! Upload failed for UID b'180' !!!
# !!! Upload failed for UID b'480' !!!
# !!! Upload failed for UID b'366' !!!
# !!! Upload failed for UID b'170' !!!
# !!! Upload failed for UID b'280' !!!
# !!! Upload failed for UID b'468' !!!
# !!! Upload failed for UID b'281' !!!
# !!! Upload failed for UID b'236' !!!
# !!! Upload failed for UID b'111' !!!
# !!! Upload failed for UID b'231' !!!
# !!! Upload failed for UID b'432' !!!
# !!! Upload failed for UID b'145' !!!
# !!! Upload failed for UID b'293' !!!
# !!! Upload failed for UID b'156' !!!
# !!! Upload failed for UID b'258' !!!
# !!! Upload failed for UID b'140' !!!
# !!! Upload failed for UID b'198' !!!
# !!! Upload failed for UID b'338' !!!
# !!! Upload failed for UID b'296' !!!
# !!! Upload failed for UID b'261' !!!
# !!! Upload failed for UID b'329' !!!
# !!! Upload failed for UID b'38' !!!
# !!! Upload failed for UID b'401' !!!
# !!! Upload failed for UID b'294' !!!
# !!! Upload failed for UID b'181' !!!
# !!! Upload failed for UID b'351' !!!
# !!! Upload failed for UID b'408' !!!
# !!! Upload failed for UID b'467' !!!
# !!! Upload failed for UID b'34' !!!
# !!! Upload failed for UID b'312' !!!
# !!! Upload failed for UID b'412' !!!
# !!! Upload failed for UID b'125' !!!
# !!! Upload failed for UID b'324' !!!
# !!! Upload failed for UID b'20' !!!
# !!! Upload failed for UID b'292' !!!
# !!! Upload failed for UID b'154' !!!
# !!! Upload failed for UID b'308' !!!
# !!! Upload failed for UID b'287' !!!
# !!! Upload failed for UID b'241' !!!
# !!! Upload failed for UID b'166' !!!
# !!! Upload failed for UID b'423' !!!
# !!! Upload failed for UID b'176' !!!
# !!! Upload failed for UID b'93' !!!
# !!! Upload failed for UID b'246' !!!
# !!! Upload failed for UID b'203' !!!
# !!! Upload failed for UID b'490' !!!
# !!! Upload failed for UID b'76' !!!
# !!! Upload failed for UID b'62' !!!
# !!! Upload failed for UID b'242' !!!
# !!! Upload failed for UID b'89' !!!
# !!! Upload failed for UID b'326' !!!
# !!! Upload failed for UID b'123' !!!
# !!! Upload failed for UID b'126' !!!
# !!! Upload failed for UID b'40' !!!
# !!! Upload failed for UID b'274' !!!
# !!! Upload failed for UID b'349' !!!
# !!! Upload failed for UID b'459' !!!
# !!! Upload failed for UID b'98' !!!
# !!! Upload failed for UID b'24' !!!
# !!! Upload failed for UID b'304' !!!
# !!! Upload failed for UID b'260' !!!
# !!! Upload failed for UID b'73' !!!
# !!! Upload failed for UID b'42' !!!
# !!! Upload failed for UID b'195' !!!
# !!! Upload failed for UID b'61' !!!
# !!! Upload failed for UID b'32' !!!
# !!! Upload failed for UID b'475' !!!
# !!! Upload failed for UID b'25' !!!
# !!! Upload failed for UID b'415' !!!
# !!! Upload failed for UID b'374' !!!
# !!! Upload failed for UID b'225' !!!
# !!! Upload failed for UID b'431' !!!
# !!! Upload failed for UID b'266' !!!
# !!! Upload failed for UID b'158' !!!
# !!! Upload failed for UID b'430' !!!
# !!! Upload failed for UID b'435' !!!
# !!! Upload failed for UID b'185' !!!
# !!! Upload failed for UID b'135' !!!
# !!! Upload failed for UID b'358' !!!
# !!! Upload failed for UID b'12' !!!
# !!! Upload failed for UID b'316' !!!
# !!! Upload failed for UID b'476' !!!
# !!! Upload failed for UID b'334' !!!
# !!! Upload failed for UID b'377' !!!
# !!! Upload failed for UID b'277' !!!
# !!! Upload failed for UID b'193' !!!
# !!! Upload failed for UID b'171' !!!
# !!! Upload failed for UID b'454' !!!
# !!! Upload failed for UID b'59' !!!
# !!! Upload failed for UID b'421' !!!
# !!! Upload failed for UID b'488' !!!
# !!! Upload failed for UID b'19' !!!
# !!! Upload failed for UID b'368' !!!
# !!! Upload failed for UID b'33' !!!
# !!! Upload failed for UID b'393' !!!
# !!! Upload failed for UID b'71' !!!
# !!! Upload failed for UID b'314' !!!
# !!! Upload failed for UID b'378' !!!
# !!! Upload failed for UID b'136' !!!
# !!! Upload failed for UID b'82' !!!
# !!! Upload failed for UID b'299' !!!
# !!! Upload failed for UID b'60' !!!
# !!! Upload failed for UID b'455' !!!
# !!! Upload failed for UID b'222' !!!
# !!! Upload failed for UID b'240' !!!
# !!! Upload failed for UID b'7' !!!
# !!! Upload failed for UID b'179' !!!
# !!! Upload failed for UID b'319' !!!
# !!! Upload failed for UID b'394' !!!
# !!! Upload failed for UID b'131' !!!
# !!! Upload failed for UID b'297' !!!
# !!! Upload failed for UID b'417' !!!
# !!! Upload failed for UID b'305' !!!
# !!! Upload failed for UID b'337' !!!
# !!! Upload failed for UID b'479' !!!
# !!! Upload failed for UID b'183' !!!
# !!! Upload failed for UID b'218' !!!
# !!! Upload failed for UID b'332' !!!

# %%
ad = main.all_data()
ad.sort()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   from ipykernel import kernelapp as app
# Empty DataFrame
# Columns: []
# Index: []

# %%
ser = ad['rent']
ser.index = ad['area_code']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4443)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4289)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13733)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13687)()
#
# KeyError: 'rent'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-f23dff7ee21d> in <module>()
# ----> 1 ser = ad['rent']
#       2 ser.index = ad['area_code']
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3539
#    3540             if not isnull(item):
# -> 3541                 loc = self.items.get_loc(item)
#    3542             else:
#    3543                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4443)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4289)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13733)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13687)()
#
# KeyError: 'rent'

# %%
ax = ser.plot(kind='bar')
ax.set_ylabel('Rent £ psf')

# %%
gby = ad.groupby('area_code')

# %%
gby['rent'].describe().unstack()

# %%
import plotly.plotly as py
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')

for col in df.columns:
    df[col] = df[col].astype(str)

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

df['text'] = df['state'] + '<br>' +\
    'Beef '+df['beef']+' Dairy '+df['dairy']+'<br>'+\
    'Fruits '+df['total fruits']+' Veggies ' + df['total veggies']+'<br>'+\
    'Wheat '+df['wheat']+' Corn '+df['corn']

data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df['code'],
        z = df['total exports'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Millions USD")
        ) ]

layout = dict(
        title = '2011 US Agriculture Exports by State<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )

# %%
import plotly.tools as tls
tls.set_credentials_file(username='RobertJohnCooper', api_key='cwL23epHXJNZdV19SVTr')
