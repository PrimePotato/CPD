# %%
import main

# %%
# %matplotlib inline

# %%
# main.del_all()

# %%
# main.update_database()

# %%
ad = main.all_data()
ad.sort()
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   from ipykernel import kernelapp as app
#                                                address area_code date_posted  \
# id
# 0    Avenfield House, 118-127 Park Ln, Mayfair, Lon...       W1K  2017-05-04
# 1         188 Baker St, Marylebone, London NW1 5TE, UK       NW1  2017-04-24
# 2                 32 Saffron Hill, London EC1N 8FH, UK      EC1N  2017-04-24
# 3                   17 Macklin St, London WC2B 5NR, UK      WC2B  2017-04-24
# 4                  44 Bedford Row, London WC1R 4LL, UK      WC1R  2017-04-24
# 5       40 Bernard St, Bloomsbury, London WC1N 1LE, UK      WC1N  2017-04-24
# 6             67-68 Hatton Garden, London EC1N 8JY, UK       EC1  2017-04-25
# 7             10 Dover St, Mayfair, London W1S 4LQ, UK       W1S  2017-04-25
# 8        63 Margaret St, Fitzrovia, London W1W 8SW, UK       W1W  2017-04-25
# ...

# %%
ser = ad['rent']
ser.index = ad['area_code']

# %%
ax = ser.plot(kind='bar', figsize=(15,10))
ax.set_ylabel('Rent £ psf')

# %%
gby = ad.groupby('area_code')

# %%
d =gby['rent'].describe().unstack()

# %%
import plotly.plotly as py
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_us_ag_exports.csv')

for col in df.columns:
    df[col] = df[col].astype(str)

scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
            [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

df['text'] = df['state'] + '<br>' +\
    'Beef '+df['beef']+' Dairy '+df['dairy']+'<br>'+\
    'Fruits '+df['total fruits']+' Veggies ' + df['total veggies']+'<br>'+\
    'Wheat '+df['wheat']+' Corn '+df['corn']

data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df['code'],
        z = df['total exports'].astype(float),
        locationmode = 'USA-states',
        text = df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Millions USD")
        ) ]

layout = dict(
        title = '2011 US Agriculture Exports by State<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~robertjohncooper/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~robertjohncooper/0.embed" height="525px" width="100%"></iframe>

# %%
import plotly.tools as tls
tls.set_credentials_file(username='RobertJohnCooper', api_key='cwL23epHXJNZdV19SVTr')

# %%
d.index
# Out:
# Index(['E1', 'E18H', 'E2', 'EC1', 'EC1A', 'EC1M', 'EC1N', 'EC1R', 'EC1Y',
#        'EC2A', 'EC2M', 'EC3V', 'N1', 'N19', 'NW1', 'NW5', 'R7', 'SE1', 'SW1',
#        'SW10', 'SW1A', 'SW1E', 'SW1P', 'SW1Y', 'SW9', 'TW9', 'W1', 'W11',
#        'W1B', 'W1C', 'W1D', 'W1F', 'W1H', 'W1J', 'W1K', 'W1S', 'W1T', 'W1U',
#        'W1W', 'W2', 'W8', 'WC1A', 'WC1B', 'WC1H', 'WC1N', 'WC1R', 'WC1V',
#        'WC1X', 'WC2', 'WC2B', 'WC2E', 'WC2H', 'WC2N', 'WC2R'],
#       dtype='object', name='area_code')
