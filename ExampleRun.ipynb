# %%
import main

# %%
# %matplotlib inline

# %%
# main.del_all()
# main.update_database()

# %%
ad = main.all_disposals()
# ad.sort()

# %%
gby = ad.groupby('my_hood')

# %%
gby['rent'].mean().plot(kind='bar', figsize=(15,10), title='Rent £psf by area')

# %%
aa = main.all_acquisition_areas()

# %%
ga = aa.groupby('description')
ga['id'].count().plot(kind='bar', figsize=(15,10), title='Acquisitions by area')
