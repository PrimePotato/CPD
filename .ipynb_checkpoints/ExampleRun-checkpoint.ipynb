# %%
import main

# %%
# %matplotlib inline

# %%
# main.del_all()

# %%
# main.update_database()

# %%
ad = main.all_data()
ad
# Out:
#                                               address area_code date_posted  \
# id
# 0                          East Rd, London N1 6AD, UK      N16A  2017-04-19
# 1                     3 Sheldon Square, London W2, UK        W2  2017-04-12
# 2   4 Matthew Parker St, Westminster, London SW1H ...      SW1H  2017-04-18
# 3                     3 Sheldon Square, London W2, UK        W2  2017-04-18
# 4   6 Cavendish Square, Marylebone, London W1G 0PD...       W1G  2017-04-12
# 5                        71 Kingsway, London WC2B, UK      WC2B  2017-04-12
# 6   Shropshire House, 2-10 Capper St, Fitzrovia, L...      WC1E  2017-04-19
# 7                        71 Kingsway, London WC2B, UK      WC2B  2017-04-12
# 8                  240 Blackfriars Rd, London SE1, UK       SE1  2017-04-19
# 9                    6 Brownlow Mews, London WC1N, UK      WC1N  2017-04-19
# 10          10 Pollen St, Mayfair, London W1S 1NQ, UK        W1  2017-04-19
# ...

# %%
ser = ad['rent']
ser.index = ad['area_code']

# %%
ax = ser.plot(kind='bar')
ax.set_ylabel('Rent £ psf')

# %%
gby = ad.groupby('area_code')

# %%
gby['rent'].summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-930eec1b0825> in <module>()
# ----> 1 gby['rent'].summary()
#
# C:\Anaconda3\lib\site-packages\pandas\core\groupby.py in __getattr__(self, attr)
#     527
#     528         raise AttributeError("%r object has no attribute %r" %
# --> 529                              (type(self).__name__, attr))
#     530
#     531     plot = property(GroupByPlot)
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'summary'

# %%
s =gby['rent'].describe()
